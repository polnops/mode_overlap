# %%
from mode_overlap_functions import *
from commons import *
from waist_fit import *

# %% [markdown]
# # loading, reshaping, clipping COMSOL .dat

# %%
#13a is 2 um, 14 is 3um

# %%
dat_2um, param_list_2um = loadData('../normE_all13a.dat')
w_2um = plotandfitNorm(dat_2um, param_list_2um, bound=3000, res = 100j)

# %%
plotWaists(param_list_2um[::4],np.abs(w_2um))

# %%
dat_3um, param_list_3um = loadData('../normE_all14.dat')

# %%
w_3um = plotandfitNorm(dat_3um, param_list_3um, bound=3000, res = 100j)

# %%
plotWaists(param_list_3um[::4],np.abs(w_3um))

# %%
plt.plot(param_list_3um[::4], np.abs(w_3um)*1e-3, marker='o', linestyle='', label = "3 um thickness")
plt.plot(param_list_2um[::4], np.abs(w_2um)*1e-3, marker='o', linestyle='', label = "2 um thickness")


plt.locator_params(axis="x", nbins=4)
plt.ylabel("mode overlap")
plt.legend()
plt.xlabel("width (nm)")
plt.show()

# %%
dat, param_list = loadData('../normE_all13a.dat')
plotComplexData(dat, param_list, bound=2500)

b1, b2, b3 = convolveComplex(dat_fiber, dat, param_list,
                 bound=2000, scale = 1,
                 res=100j, plotflag1 = False,
                 plotflag2=True, fitflag= True,
                 i=0)

# %%
plt.plot(a1, a3, marker='o', linestyle='', label = "3 um thickness")
plt.plot(b1, b3, marker='o', linestyle='', label = "2 um thickness")


plt.locator_params(axis="x", nbins=4)
plt.ylabel("mode overlap")
plt.legend()
plt.xlabel("width (nm)")
plt.show()
