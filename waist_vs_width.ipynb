# %%
from mode_overlap_functions import *
from commons import *

# %% [markdown]
# # loading, reshaping, clipping COMSOL .dat

# %%
dat, param_list = loadData('../normE_all14.dat')

# %%
plotData(dat_fiber, range(4), bound=2500)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-c966dc7fb9f8> in <module>
# ----> 1 plotData(dat_fiber, range(4), bound=2500)
#
# TypeError: plotData() got multiple values for argument 'bound'

# %%
plotData(dat, param_list, bound=2500)

# %%
a1, a2, a3 = convolveComplex(dat_fiber, dat, param_list,
                 bound=2000, scale = 1,
                 res=100j, plotflag1 = False,
                 plotflag2=True, fitflag= True,
                 i=0)

# %%
dat, param_list = loadData('../normE_all13a.dat')
plotComplexData(dat, param_list, bound=2500)

b1, b2, b3 = convolveComplex(dat_fiber, dat, param_list,
                 bound=2000, scale = 1,
                 res=100j, plotflag1 = False,
                 plotflag2=True, fitflag= True,
                 i=0)

# %%
plt.plot(a1, a3, marker='o', linestyle='', label = "3 um thickness")
plt.plot(b1, b3, marker='o', linestyle='', label = "2 um thickness")


plt.locator_params(axis="x", nbins=4)
plt.ylabel("mode overlap")
plt.legend()
plt.xlabel("width (nm)")
plt.show()
